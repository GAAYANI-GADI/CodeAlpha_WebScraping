# %%
# CodeAlpha Web Scraping Project

This notebook demonstrates how to scrape data using Python and BeautifulSoup.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

url = "https://quotes.toscrape.com/"
response = requests.get(url)

soup = BeautifulSoup(response.text, "html.parser")

quotes = [q.text for q in soup.find_all("span", class_="text")]
authors = [a.text for a in soup.find_all("small", class_="author")]

df = pd.DataFrame({
    "Quote": quotes,
    "Author": authors
})

df.head()

# %%
df.to_csv("../data/quotes_data.csv", index=False)
print("CSV saved successfully")
